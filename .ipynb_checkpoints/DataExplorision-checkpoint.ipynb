# %%
# Must be included at the beginning of each new notebook. Remember to change the app name.
import findspark
findspark.init('/home/ubuntu/spark-3.2.1-bin-hadoop2.7')
import pyspark
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('basics').getOrCreate()

# %%
df = spark.read.csv('data/tmdb_5000_movies_fixed1_fix.csv')

# %%
df.show(1)
# Out:
# +------+---+-----------------+----------+-------+-------+------+-----+------------+----------+-----+------------+------------------+
# |   _c0|_c1|              _c2|       _c3|    _c4|    _c5|   _c6|  _c7|         _c8|       _c9| _c10|        _c11|              _c12|
# +------+---+-----------------+----------+-------+-------+------+-----+------------+----------+-----+------------+------------------+
# |budget| id|original_language|popularity|revenue|runtime|status|title|vote_average|vote_count|genre|release_date|production_country|
# +------+---+-----------------+----------+-------+-------+------+-----+------------+----------+-----+------------+------------------+
# only showing top 1 row

# %%
# Optionally, rename columns for better clarity
df = df.withColumnRenamed("_c0", "budget") \
       .withColumnRenamed("_c1", "id") \
       .withColumnRenamed("_c2", "original_language") \
       .withColumnRenamed("_c3", "popularity") \
       .withColumnRenamed("_c4", "revenue") \
       .withColumnRenamed("_c5", "runtime") \
       .withColumnRenamed("_c6", "status") \
       .withColumnRenamed("_c7", "title") \
       .withColumnRenamed("_c8", "vote_average") \
       .withColumnRenamed("_c9", "vote_count") \
       .withColumnRenamed("_c10", "genre") \
       .withColumnRenamed("_c11", "release_date") \
       .withColumnRenamed("_c12", "production_country")

# %%
df.printSchema()
# Out:
# root
#  |-- budget: string (nullable = true)
#  |-- id: string (nullable = true)
#  |-- original_language: string (nullable = true)
#  |-- popularity: string (nullable = true)
#  |-- revenue: string (nullable = true)
#  |-- runtime: string (nullable = true)
#  |-- status: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- vote_average: string (nullable = true)
#  |-- vote_count: string (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- release_date: string (nullable = true)
#  |-- production_country: string (nullable = true)

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import IntegerType, DoubleType, DateType

# Convert columns to the desired data types
df = df.withColumn("budget", df["budget"].cast(IntegerType()))
df = df.withColumn("id", df["id"].cast(IntegerType()))
df = df.withColumn("popularity", df["popularity"].cast(DoubleType()))
df = df.withColumn("revenue", df["revenue"].cast(IntegerType()))
df = df.withColumn("runtime", df["runtime"].cast(IntegerType()))
df = df.withColumn("vote_average", df["vote_average"].cast(DoubleType()))
df = df.withColumn("vote_count", df["vote_count"].cast(IntegerType()))
df = df.withColumn("release_date", to_date(df["release_date"], "yyyy-MM-dd"))

# Print the updated schema
df.printSchema()
# Out:
# root
#  |-- budget: integer (nullable = true)
#  |-- id: integer (nullable = true)
#  |-- original_language: string (nullable = true)
#  |-- popularity: double (nullable = true)
#  |-- revenue: integer (nullable = true)
#  |-- runtime: integer (nullable = true)
#  |-- status: string (nullable = true)
#  |-- title: string (nullable = true)
#  |-- vote_average: double (nullable = true)
#  |-- vote_count: integer (nullable = true)
#  |-- genre: string (nullable = true)
#  |-- release_date: date (nullable = true)
#  |-- production_country: string (nullable = true)

# %%
from itertools import combinations

# Define the selected columns
selected_columns = ["budget", "revenue", "runtime", "vote_count", "popularity", "vote_average"]

# Compute the correlation matrix for each pair of columns
correlation_matrix = []

for col1, col2 in combinations(selected_columns, 2):
    corr_value = df.select(corr(col1, col2)).collect()[0][0]
    correlation_matrix.append((col1, col2, corr_value))

# Print the correlation matrix
print("Correlation Matrix:")
for col1, col2, corr_value in correlation_matrix:
    print(f"Correlation between {col1} and {col2}: {corr_value}")
# Out:
# Correlation Matrix:
# Correlation between budget and revenue: 0.7365835799393109
# Correlation between budget and runtime: 0.26985137798455106
# Correlation between budget and vote_count: 0.5931803381308591
# Correlation between budget and popularity: 0.5054139990665325
# Correlation between budget and vote_average: 0.09314574534816306
# Correlation between revenue and runtime: 0.2501018248718594
# Correlation between revenue and vote_count: 0.7794954885936858
# Correlation between revenue and popularity: 0.6507645887448014
# Correlation between revenue and vote_average: 0.19978607495484785
# Correlation between runtime and vote_count: 0.2719441984500503
# Correlation between runtime and popularity: 0.22550205846049795
# Correlation between runtime and vote_average: 0.37504568036518865
# Correlation between vote_count and popularity: 0.7781298890348527
# Correlation between vote_count and vote_average: 0.31299740399575865
# Correlation between popularity and vote_average: 0.2739518286190272

# %% [markdown]
# ### show each feature statistic

# %%
# Get the list of column names
columns = df.columns

# Iterate over each column
for column in columns:
    print(f"Statistics for column '{column}':")
    
    # Calculate and display statistics for the current column
    df.describe(column).show()
# Out:
# Statistics for column 'budget':
# +-------+-------------------+
# |summary|             budget|
# +-------+-------------------+
# |  count|               4803|
# |   mean|2.904503987528628E7|
# | stddev|4.072239125855028E7|
# |    min|                  0|
# |    max|          380000000|
# +-------+-------------------+
#
# Statistics for column 'id':
# +-------+------------------+
# |summary|                id|
# +-------+------------------+
# |  count|              4803|
# |   mean|57165.484280657925|
# | stddev|  88694.6140333181|
# |    min|                 5|
# |    max|            459488|
# +-------+------------------+
#
# Statistics for column 'original_language':
# +-------+-----------------+
# |summary|original_language|
# +-------+-----------------+
# |  count|             4804|
# |   mean|             null|
# | stddev|             null|
# |    min|               af|
# |    max|               zh|
# +-------+-----------------+
#
# Statistics for column 'popularity':
# +-------+------------------+
# |summary|        popularity|
# +-------+------------------+
# |  count|              4803|
# |   mean| 21.49230058817409|
# | stddev|31.816649749537767|
# |    min|               0.0|
# |    max|        875.581305|
# +-------+------------------+
#
# Statistics for column 'revenue':
# +-------+--------------------+
# |summary|             revenue|
# +-------+--------------------+
# |  count|                4802|
# |   mean|  8.16971849972928E7|
# | stddev|1.5812269139043728E8|
# |    min|                   0|
# |    max|          1845034188|
# +-------+--------------------+
#
# Statistics for column 'runtime':
# +-------+------------------+
# |summary|           runtime|
# +-------+------------------+
# |  count|              4801|
# |   mean|106.87585919600083|
# | stddev|22.611934588844232|
# |    min|                 0|
# |    max|               338|
# +-------+------------------+
#
# Statistics for column 'status':
# +-------+---------------+
# |summary|         status|
# +-------+---------------+
# |  count|           4804|
# |   mean|           null|
# | stddev|           null|
# |    min|Post Production|
# |    max|         status|
# +-------+---------------+
#
# Statistics for column 'title':
# +-------+------------------+
# |summary|             title|
# +-------+------------------+
# |  count|              4804|
# |   mean|1125.1666666666667|
# | stddev| 935.2601809446428|
# |    min|           #Horror|
# |    max|          �on Flux|
# +-------+------------------+
#
# Statistics for column 'vote_average':
# +-------+------------------+
# |summary|      vote_average|
# +-------+------------------+
# |  count|              4803|
# |   mean| 6.092171559442011|
# | stddev|1.1946121628478916|
# |    min|               0.0|
# |    max|              10.0|
# +-------+------------------+
#
# Statistics for column 'vote_count':
# +-------+------------------+
# |summary|        vote_count|
# +-------+------------------+
# |  count|              4803|
# |   mean| 690.2179887570269|
# | stddev|1234.5858907715415|
# |    min|                 0|
# |    max|             13752|
# +-------+------------------+
#
# Statistics for column 'genre':
# +-------+------+
# |summary| genre|
# +-------+------+
# |  count|  4776|
# |   mean|  null|
# | stddev|  null|
# |    min|Action|
# |    max|others|
# +-------+------+
#
# Statistics for column 'release_date':
# +-------+
# |summary|
# +-------+
# |  count|
# |   mean|
# | stddev|
# |    min|
# |    max|
# +-------+
#
# Statistics for column 'production_country':
# +-------+------------------+
# |summary|production_country|
# +-------+------------------+
# |  count|              4928|
# |   mean|              null|
# | stddev|              null|
# |    min|       afghanistan|
# |    max|      united_state|
# +-------+------------------+

# %% [markdown]
# ### plot genre and production country

# %%
# Group by the correct column name "_c10" (assuming it contains genre information)
genre_counts = df.groupBy("genre").count()

# Convert to Pandas DataFrame for plotting
genre_counts_pd = genre_counts.toPandas()

# Plotting the bar plot
import matplotlib.pyplot as plt

genre_counts_pd.set_index("genre", inplace=True)
genre_counts_pd.plot(kind='bar', legend=False)
plt.xlabel('Genre')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Genres')
plt.show()

# Show unique genres
unique_genres = df.select("genre").distinct().collect()
unique_genres = [row['genre'] for row in unique_genres]
print(unique_genres)
# Out:
# ['Crime', 'Romance', 'Thriller', None, 'others', 'Animation', 'Advanture', 'genre', 'Comedy', 'Action', 'Science fiction']

# %%
# Group by the correct column name and count occurrences
country_counts = df.groupBy("production_country").count()

# Convert to Pandas DataFrame for plotting
country_counts_pd = country_counts.toPandas()

# Plotting the bar plot
country_counts_pd.plot(kind='bar', x='production_country', y='count')
plt.xlabel('Production Country')
plt.ylabel('Frequency')
plt.title('Frequency Distribution of Production Countries')
plt.show()

# Print unique production countries
unique_countries = df.select("production_country").distinct().rdd.map(lambda x: x[0]).collect()
print("Unique Production Countries:", unique_countries)
# Out:
# Unique Production Countries: ['finland', 'greece', 'israel', 'poland', 'fiji', '#REF!', ' libyan_arab_jamahiriya', 'czech republic', 'malta', 'morocco', 'lebanon', 'japan', ' austria', 'luxembourg', 'thailand', 'india', 'hongkong', ' australia', 'united_arab', 'sweden', 'indonesia', ' dominican republic', 'new_zealand', ' afghanistan', 'brazil', 'jamaica', 'netherlands', 'south_africa', 'canada', 'france', 'cameroon', 'swizerland', 'iceland', 'iran', 'united_kingdom', 'argentina', 'USA', 'turkey', 'south_korea', 'kyrgyz_republic', 'production_country', 'singapore', ' bolivia', 'germany', 'guyana', 'panama', 'bosnia', 'malaysia', 'russia', 'guadaloupe', 'italy', 'ireland', ' belgium', 'romania', 'norway', 'denmark', ' bahamas', 'slovenia', 'philippines', 'peru', 'china', 'kenya', 'cyprus', 'bhutan', 'pakistan', ' bulgaria', 'united_state', ' aruba', 'hungary', 'spain', ' algeria', 'mexico', 'ecuador']

# %% [markdown]
# ### plot budget and revenue

# %%
from scipy.interpolate import make_interp_spline
import numpy as np

# Convert Spark DataFrame to Pandas DataFrame
df_pandas = df.toPandas()

# Drop rows with missing values and duplicates
df_clean = df_pandas.copy().dropna().drop_duplicates(subset=['budget'])

# Sort values by 'budget'
df_clean = df_clean.sort_values(by='budget')

# Create a spline interpolation function
x = df_clean['budget']
y = df_clean['revenue']
x_smooth = np.linspace(x.min(), x.max(), 500)  
spl = make_interp_spline(x, y, k=1)  # Adjust the smoothness (degree of the spline) as needed
y_smooth = spl(x_smooth)

# Plot with the smoothed line
plt.plot(x_smooth, y_smooth, label='Revenue vs Budget (Smoothed)')
plt.xlabel('Budget')
plt.ylabel('Revenue')
plt.title('Revenue vs Budget')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Convert PySpark DataFrame to Pandas DataFrame
pandas_df = df.select("vote_average", "revenue").toPandas()

# Plot the scatter plot
plt.plot(pandas_df["vote_average"], pandas_df["revenue"], 'o', label='Revenue vs vote_average')

plt.xlabel('vote_average')  # Adjust the x-axis label if needed
plt.ylabel('Revenue')  # Adjust the y-axis label if needed
plt.title('Revenue vs vote_average')  # Adjust the title if needed
plt.legend()  # Show legend
plt.grid(True)  # Add gridlines
plt.show()

# %%
# Filter out rows with missing or NaN values in the revenue column
df_clean = df.filter(df['revenue'].isNotNull())

# Aggregate revenue by genre
genre_revenue = df_clean.groupBy('genre').sum('revenue')

# Convert PySpark DataFrame to Pandas DataFrame
pandas_genre_revenue = genre_revenue.toPandas()

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(pandas_genre_revenue['sum(revenue)'], labels=pandas_genre_revenue['genre'], autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Revenue by Genre')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.show()

# %%
# Filter out rows with null or NaN values in the 'sum(revenue)' column
pandas_production_country_revenue = pandas_production_country_revenue.copy().dropna(subset=['sum(revenue)'])

# Create pie chart
plt.figure(figsize=(8, 8))
plt.pie(pandas_production_country_revenue['sum(revenue)'], labels=pandas_production_country_revenue['production_country'], autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Revenue by Production Country')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle

plt.show()

# %% [markdown]
# ### checking null value

# %%
from pyspark.sql.functions import col

# Filter rows with any null values
nan_rows = df.filter(
    (col("budget").isNull()) |
    (col("id").isNull()) |
    (col("original_language").isNull()) |
    (col("popularity").isNull()) |
    (col("revenue").isNull()) |
    (col("runtime").isNull()) |
    (col("status").isNull()) |
    (col("title").isNull()) |
    (col("vote_average").isNull()) |
    (col("vote_count").isNull()) |
    (col("genre").isNull()) |
    (col("release_date").isNull()) |
    (col("production_country").isNull())
)

# Show rows with null values
nan_rows.show()
# Out:
# +---------+------+-----------------+----------+---------+-------+--------+--------------------+------------+----------+------+------------+------------------+
# |   budget|    id|original_language|popularity|  revenue|runtime|  status|               title|vote_average|vote_count| genre|release_date|production_country|
# +---------+------+-----------------+----------+---------+-------+--------+--------------------+------------+----------+------+------------+------------------+
# |     null|  null|original_language|      null|     null|   null|  status|               title|        null|      null| genre|        null|production_country|
# |237000000| 19995|               en|150.437577|     null|    162|Released|              Avatar|         7.2|     11800|Action|  2009-12-10|               USA|
# |258000000|   559|               en|115.699814|890871626|    139|Released|        Spider-Man 3|         5.9|      3576|Action|        null|               USA|
# | 15000000|370980|               it|  0.738646|        0|   null|Released|Chiamatemi France...|         7.3|        12|Comedy|  2015-12-03|             italy|
# |        0|191229|               en|  0.214704|        0|     88|Released|              Iguana|         6.0|         1|  null|  1988-04-01|             #REF!|
# |        0|346081|               en|  0.296981|        0|      0|Released|           Sardaarji|         9.5|         2|  null|  2015-06-26|             india|
# |        0|371085|               en|  0.027801|        0|      0|Released|           Sharkskin|         0.0|         0|  null|  2015-01-01|             #REF!|
# |  2000000| 48382|               en|  0.031947|  1672730|    120|Released|The Book of Mormo...|         5.0|         2|  null|  2003-09-12|             #REF!|
# |        0|325140|               en|  0.001186|        0|      0|Released|Hum To Mohabbat K...|         0.0|         0|  null|  2000-05-26|             #REF!|
# |        2|459488|               en|  0.050625|        0|   null|Released|To Be Frank, Sina...|         0.0|         0|others|  2015-12-12|    united_kingdom|
# |        1|357834|               en|  0.025364|        0|     99|Released|        The Algerian|         0.0|         0|  null|  2015-08-07|           algeria|
# |  1200000|137955|               en|  0.057564|        0|     84|Released|           Crowsnest|         4.8|        12|  null|  2012-01-01|            canada|
# |        0|206412|               en|  0.690089|        0|     90|Released|Lisa Picard Is Fa...|         4.0|         1|  null|  2000-05-14|             #REF!|
# |        0|219716|               en|  0.547654|        0|     96|Released|            Sparkler|         0.0|         1|  null|  1999-03-19|             #REF!|
# |        0|335874|               en|  0.243853|        0|     90|Released|           Childless|         4.5|         2|  null|  2015-04-03|      united_state|
# |        0|279759|               en|  0.006943|        0|      0|Released| Harrison Montgomery|         0.0|         0|  null|  2008-01-01|             #REF!|
# |        0|331493|               en|  0.012942|        0|      0|Released|Light from the Da...|         0.0|         0|  null|  2014-01-01|             #REF!|
# |        0|294550|               en|  0.021419|        0|     96|Released|The Outrageous So...|         0.0|         0|  null|  2014-05-02|             #REF!|
# |        0|380097|               en|       0.0|        0|      0|Released|America Is Still ...|         0.0|         0|  null|        null|             #REF!|
# |   500000|297100|               en|  0.073079|        0|     84|Released|The Little Ponder...|         2.0|         1|  null|  2014-09-11|             #REF!|
# +---------+------+-----------------+----------+---------+-------+--------+--------------------+------------+----------+------+------------+------------------+
# only showing top 20 rows

# %%
zero_budget = df.filter(df["budget"] == 0)
zero_budget.show()
# Out:
# +------+------+-----------------+----------+---------+-------+--------+--------------------+------------+----------+---------------+------------+------------------+
# |budget|    id|original_language|popularity|  revenue|runtime|  status|               title|vote_average|vote_count|          genre|release_date|production_country|
# +------+------+-----------------+----------+---------+-------+--------+--------------------+------------+----------+---------------+------------+------------------+
# |     0| 10588|               en| 18.251129|        0|     82|Released|  The Cat in the Hat|         4.9|       366|         Comedy|  2003-11-21|      united_state|
# |     0| 77953|               en| 16.460356|104907746|     85|Released|        The Campaign|         5.6|       578|         Comedy|  2012-08-09|      united_state|
# |     0|258509|               en| 27.867368|233755553|     92|Released|Alvin and the Chi...|         5.8|       428|      Advanture|  2015-12-17|      united_state|
# |     0| 51052|               en|  19.83683|        0|     97|Released|    Arthur Christmas|         6.7|       333|         Comedy|  2011-02-22|      united_state|
# |     0| 16858|               en|  5.159407| 37823676|    123|Released|       All That Jazz|         7.3|        85|         Comedy|  1979-12-20|      united_state|
# |     0| 12096|               en| 25.450534|        0|     93|Released|    The Pink Panther|         5.6|       550|         Action|  2006-01-18|      united_state|
# |     0|161795|               en|  0.605645|        0|    117|Released|             D�j� Vu|         8.0|         1|        Romance|  1998-04-22|      united_state|
# |     0|330770|               fr|  3.300061|        0|     81|Released|           Evolution|         6.4|        47|         others|  2015-09-14|           belgium|
# |     0|  9433|               en| 20.632673| 43312294|    117|Released|            The Edge|         6.7|       349|         Action|  1997-09-06|      united_state|
# |     0| 36970|               en| 10.706613| 19406406|     84|Released|              Oceans|         7.3|       111|         others|  2009-10-17|            france|
# |     0| 25769|               en| 12.708963|  5802422|     84|Released|            Carriers|         5.8|       282|         Action|  2009-09-04|      united_state|
# |     0| 10395|               en| 13.758526|        0|    125|Released|                Wolf|         6.0|       216|Science fiction|  1994-06-17|      united_state|
# |     0| 11535|               en|  9.306253|        0|     98|Released|          Rollerball|         3.4|       106|         Action|  2002-02-08|           germany|
# |     0| 11199|               en| 31.719463|253625427|    100|Released|           Wild Hogs|         5.6|       648|         Action|  2007-03-02|      united_state|
# |     0| 10628|               en| 10.292864|        0|     89|Released|       Kangaroo Jack|         4.3|       203|         Comedy|  2003-01-17|         australia|
# |     0| 10771|               en| 21.549232|        0|     98|Released|          The Tuxedo|         5.3|       483|       Thriller|  2002-09-27|      united_state|
# |     0| 10040|               en| 19.998581|        0|    115|Released|Miss Congeniality...|         5.3|       425|         Action|  2005-03-11|      united_state|
# |     0| 87825|               en| 18.587114|        0|    111|Released|Trouble with the ...|         6.6|       366|         Comedy|  2012-09-21|      united_state|
# |     0|  9513|               en| 16.930969|141702264|     78|Released|Garfield: A Tail ...|         5.1|       464|      Animation|  2006-06-15|    united_kingdom|
# |     0| 13260|               en| 10.449975| 33472850|     91|Released|            Semi-Pro|         5.4|       251|         Comedy|  2008-02-28|      united_state|
# +------+------+-----------------+----------+---------+-------+--------+--------------------+------------+----------+---------------+------------+------------------+
# only showing top 20 rows

# %%
zero_revenue = df.filter(df["revenue"] == 0)
zero_revenue.show()
# Out:
# +---------+------+-----------------+----------+-------+-------+--------+------------------+------------+----------+---------------+------------+------------------+
# |   budget|    id|original_language|popularity|revenue|runtime|  status|             title|vote_average|vote_count|          genre|release_date|production_country|
# +---------+------+-----------------+----------+-------+-------+--------+------------------+------------+----------+---------------+------------+------------------+
# | 27000000| 79698|               en|  2.418535|      0|    109|Released|        The Lovers|         4.8|        34|         Action|  2015-02-13|         australia|
# |150000000|  7978|               en| 21.214571|      0|    102|Released|       The Wolfman|         5.5|       549|         Comedy|  2010-02-11|      united_state|
# |        0| 10588|               en| 18.251129|      0|     82|Released|The Cat in the Hat|         4.9|       366|         Comedy|  2003-11-21|      united_state|
# | 84000000| 10214|               en| 17.815595|      0|     94|Released|   Son of the Mask|         3.6|       338|Science fiction|  2005-02-18|           germany|
# | 90000000| 10357|               en| 19.836124|      0|    104|Released|           Volcano|         5.2|       376|Science fiction|  1997-04-25|      united_state|
# |        0| 51052|               en|  19.83683|      0|     97|Released|  Arthur Christmas|         6.7|       333|         Comedy|  2011-02-22|      united_state|
# | 84000000|146216|               en|  44.34333|      0|    116|Released|             RED 2|         6.4|      1526|         Action|  2013-07-18|            canada|
# |        0| 12096|               en| 25.450534|      0|     93|Released|  The Pink Panther|         5.6|       550|         Action|  2006-01-18|      united_state|
# |        0|161795|               en|  0.605645|      0|    117|Released|           D�j� Vu|         8.0|         1|        Romance|  1998-04-22|      united_state|
# | 90000000|  9822|               en|  6.643778|      0|    114|Released|  Mighty Joe Young|         5.9|       208|         Action|  1998-12-25|      united_state|
# | 85000000|  9678|               en| 18.335992|      0|     90|Released|      Little Nicky|         5.2|       438|         Comedy|  2000-11-10|      united_state|
# |        0|330770|               fr|  3.300061|      0|     81|Released|         Evolution|         6.4|        47|         others|  2015-09-14|           belgium|
# |  8000000|293644|               es|  0.719996|      0|     89|Released|    Top Cat Begins|         5.3|         9|         Comedy|  2015-10-30|             india|
# | 75000000|   332|               en| 17.561955|      0|     78|Released|  Inspector Gadget|         4.3|       318|         Action|  1999-07-23|      united_state|
# | 75000000|  1439|               en| 13.327372|      0|    148|Released| Anna and the King|         6.4|       197|         Comedy|  1999-12-16|          malaysia|
# |        0| 10395|               en| 13.758526|      0|    125|Released|              Wolf|         6.0|       216|Science fiction|  1994-06-17|      united_state|
# |        0| 11535|               en|  9.306253|      0|     98|Released|        Rollerball|         3.4|       106|         Action|  2002-02-08|           germany|
# | 65000000| 11820|               en| 19.718544|      0|    117|Released|   Mona Lisa Smile|         6.5|       393|         Comedy|  2003-12-19|      united_state|
# | 65000000|  9440|               en|  9.110247|      0|    143|Released|    Primary Colors|         6.1|        94|         Comedy|  1998-03-20|            france|
# | 65000000| 11983|               en| 14.866901|      0|    135|Released|     Proof of Life|         6.0|       208|         Action|  2000-12-08|      united_state|
# +---------+------+-----------------+----------+-------+-------+--------+------------------+------------+----------+---------------+------------+------------------+
# only showing top 20 rows
